# %% [markdown]
# <a href="https://colab.research.google.com/github/gp201/BERT/blob/master/create_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
from csv import writer

# %%
# tags from corpus
tagged_corpus = pd.read_csv("corpus_tags.tsv", sep="\t", names=["pmid", "start", "end", "word", "type", "umls_id"])
tagged_corpus = tagged_corpus.dropna()
tagged_corpus.iloc[610:640]
# Out:
#          pmid  start  ...       type   umls_id
# 610  26867927      0  ...       T061  C0850292
# 611  26867927     27  ...       T023  C0447025
# 612  26867927     60  ...       T080  C0332281
# 613  26867927     76  ...  T019,T047  C3163894
# 614  26867927    103  ...       T023  C0447025
# 615  26867927    143  ...       T080  C0332281
# 616  26867927    161  ...  T019,T047  C3163894
# 617  26867927    227  ...       T201  C0683325
# 618  26867927    253  ...       T052  C1283195
# 619  26867927    265  ...       T061  C3275043
# 620  26867927    304  ...       T062  C0035363
# 621  26867927    331  ...       T101  C0030705
# 622  26867927    354  ...       T061  C0547070
# 623  26867927    366  ...       T023  C0447025
# 624  26867927    404  ...       T082  C0205099
# 625  26867927    419  ...       T101  C0030705
# 626  26867927    435  ...  T019,T047  C3163894
# 627  26867927    472  ...       T023  C1180121
# 628  26867927    501  ...       T078  C0441833
# 629  26867927    526  ...       T101  C0030705
# 630  26867927    542  ...       T078  C0441833
# 631  26867927    552  ...       T170  C2708283
# 632  26867927    575  ...       T061  C0547070
# 633  26867927    636  ...       T078  C0441833
# 634  26867927    658  ...       T101  C0030705
# 635  26867927    688  ...       T078  C0441833
# 636  26867927    706  ...       T078  C0441833
# 637  26867927    757  ...       T081  C0001782
# 638  26867927    764  ...       T081  C0036878
# 639  26867927    782  ...       T047  C0004238
#
# [30 rows x 6 columns]

# %%
classes = []
with open("vocab_class.txt") as ftags:
    classes = [i.strip() for i in ftags.readlines()]
    ftags.close()
classes
# Out:
# ['T047', 'T005', 'T007', 'T016']

# %%
sentence_count = 1
def get_words_tags(text, pmid,start=0):
    words = []
    tags = []  
    row_cont = []
    typ = "O"
    global sentence_count
    df = tagged_corpus[(tagged_corpus["pmid"]==int(pmid)) & (tagged_corpus["end"] <= start + len(text)) & (tagged_corpus["start"] >= start)]
    indices = df.index.values
    #print(indices)
    for word in text.split():
        for i in indices:
            #print('jj',i)
            text2 = df.loc[i]["word"]
            #print('$$',text2.split())
            if word in text2.split() and set(df.loc[i]["type"].split(',')).intersection(classes):
                typ = df.loc[i]["type"]
                break
            else:
                typ = "O"
            #print("#",word,"#",typ)
        row_cont.append(["Sentence: " + str(sentence_count),word,typ])
    sentence_count = sentence_count + 1
    return row_cont

# %%
title_regex = re.compile("^\d+\|t\|")
abstract_regex = re.compile("^\d+\|a\|")


fr = open("corpus_pubtator.txt") #corpus file should be placed here

fw = open('dataset.csv','a')
fw_writer = writer(fw)
first_row = ["Sentence #","Word","Tag"]
fw_writer.writerow(first_row)
fw.close()

# %%
def append_list_as_row(file_name, list_of_elem):
    # Open file in append mode
    with open(file_name, 'a', newline='') as write_obj:
        # Create a writer object from csv module
        csv_writer = writer(write_obj)
        # Add contents of list as last row in the csv file
        for row in list_of_elem:
          csv_writer.writerow(row)
        blank = ['','','']
        csv_writer.writerow(blank)

# %%
abstract_count = 0
for i in fr.readlines():
    row_content = []
    line = i.strip()
    title_search = title_regex.search(line)
    abstract_search = abstract_regex.search(line)
    if title_search:
        title_line = title_regex.sub('',line)
    elif abstract_search:
        abstract = abstract_regex.sub('',line)
        pmid = int(abstract_search.group(0)[:-3])
        row_content = get_words_tags(title_line,pmid,0)
        append_list_as_row('dataset.csv', row_content)
        title_size = len(title_line) + 1                     # 1 for \n        
        for sentence in re.split("\.", abstract):
            if len(sentence) == 0:
                continue
            _size = abstract.index(sentence) + title_size
            row_content = get_words_tags(sentence, pmid,_size)
            append_list_as_row('dataset.csv', row_content)
        abstract_count += 1
        if abstract_count%10 == 0:
            print("PMID {} written to file. Abstract Count: {}".format(pmid, abstract_count))
fr.close()
print("Completed")
# Out:
# PMID 26868132 written to file. Abstract Count: 10
# PMID 27113387 written to file. Abstract Count: 20
# PMID 27233466 written to file. Abstract Count: 30
# PMID 27235977 written to file. Abstract Count: 40
# PMID 27239445 written to file. Abstract Count: 50
# PMID 27242395 written to file. Abstract Count: 60
# PMID 27245524 written to file. Abstract Count: 70
# PMID 27251117 written to file. Abstract Count: 80
# PMID 27252721 written to file. Abstract Count: 90
# PMID 27255600 written to file. Abstract Count: 100
# PMID 27257613 written to file. Abstract Count: 110
# PMID 27259647 written to file. Abstract Count: 120
# PMID 27263085 written to file. Abstract Count: 130
# PMID 27267338 written to file. Abstract Count: 140
# PMID 27271775 written to file. Abstract Count: 150
# PMID 27274087 written to file. Abstract Count: 160
# PMID 27275849 written to file. Abstract Count: 170
# PMID 27282214 written to file. Abstract Count: 180
# PMID 27284493 written to file. Abstract Count: 190
# PMID 27288403 written to file. Abstract Count: 200
# PMID 27294436 written to file. Abstract Count: 210
# PMID 27296942 written to file. Abstract Count: 220
# PMID 27299289 written to file. Abstract Count: 230
# PMID 27301681 written to file. Abstract Count: 240
# PMID 27305688 written to file. Abstract Count: 250
# PMID 27310615 written to file. Abstract Count: 260
# PMID 27312379 written to file. Abstract Count: 270
# PMID 27315518 written to file. Abstract Count: 280
# PMID 27319985 written to file. Abstract Count: 290
# PMID 27322653 written to file. Abstract Count: 300
# PMID 27328333 written to file. Abstract Count: 310
# PMID 27332346 written to file. Abstract Count: 320
# PMID 27335213 written to file. Abstract Count: 330
# PMID 27338295 written to file. Abstract Count: 340
# PMID 27340777 written to file. Abstract Count: 350
# PMID 27343757 written to file. Abstract Count: 360
# PMID 27347792 written to file. Abstract Count: 370
# PMID 27349182 written to file. Abstract Count: 380
# PMID 27352476 written to file. Abstract Count: 390
# PMID 27355434 written to file. Abstract Count: 400
# PMID 27357530 written to file. Abstract Count: 410
# PMID 27362260 written to file. Abstract Count: 420
# PMID 27366508 written to file. Abstract Count: 430
# PMID 27371819 written to file. Abstract Count: 440
# PMID 27374109 written to file. Abstract Count: 450
# PMID 27376349 written to file. Abstract Count: 460
# PMID 27381582 written to file. Abstract Count: 470
# PMID 27383575 written to file. Abstract Count: 480
# PMID 27387057 written to file. Abstract Count: 490
# PMID 27390849 written to file. Abstract Count: 500
# PMID 27392740 written to file. Abstract Count: 510
# PMID 27395784 written to file. Abstract Count: 520
# PMID 27400764 written to file. Abstract Count: 530
# PMID 27404466 written to file. Abstract Count: 540
# PMID 28055203 written to file. Abstract Count: 2570
# PMID 28057660 written to file. Abstract Count: 2580
# PMID 28061895 written to file. Abstract Count: 2590
# PMID 28063305 written to file. Abstract Count: 2600
# PMID 28065623 written to file. Abstract Count: 2610
# PMID 28068437 written to file. Abstract Count: 2620
# PMID 28070281 written to file. Abstract Count: 2630
# PMID 28072584 written to file. Abstract Count: 2640
# PMID 28074914 written to file. Abstract Count: 2650
# PMID 28077286 written to file. Abstract Count: 2660
# PMID 28080032 written to file. Abstract Count: 2670
# PMID 28083459 written to file. Abstract Count: 2680
# PMID 28086982 written to file. Abstract Count: 2690
# PMID 28088177 written to file. Abstract Count: 2700
# PMID 28090727 written to file. Abstract Count: 2710
# PMID 28093376 written to file. Abstract Count: 2720
# PMID 28096973 written to file. Abstract Count: 2730
# PMID 28098263 written to file. Abstract Count: 2740
# PMID 28100698 written to file. Abstract Count: 2750
# PMID 28103546 written to file. Abstract Count: 2760
# PMID 28105538 written to file. Abstract Count: 2770
# PMID 28107706 written to file. Abstract Count: 2780
# PMID 28110078 written to file. Abstract Count: 2790
# PMID 28112192 written to file. Abstract Count: 2800
# PMID 28115718 written to file. Abstract Count: 2810
# PMID 28118200 written to file. Abstract Count: 2820
# PMID 28121531 written to file. Abstract Count: 2830
# PMID 28123213 written to file. Abstract Count: 2840
# PMID 28125612 written to file. Abstract Count: 2850
# PMID 28127799 written to file. Abstract Count: 2860
# PMID 28129375 written to file. Abstract Count: 2870
# PMID 28132765 written to file. Abstract Count: 2880
# PMID 28135680 written to file. Abstract Count: 2890
# PMID 28139296 written to file. Abstract Count: 2900
# PMID 28143658 written to file. Abstract Count: 2910
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-192-b4e1bd0694c1> in <module>()
#      17                 continue
#      18             _size = abstract.index(sentence) + title_size
# ---> 19             row_content = get_words_tags(sentence, pmid,_size)
#      20             append_list_as_row('dataset.csv', row_content)
#      21         abstract_count += 1
#
# <ipython-input-189-0a715b9e34ea> in get_words_tags(text, pmid, start)
#      12         for i in indices:
#      13             #print('jj',i)
# ---> 14             text2 = df.loc[i]["word"]
#      15             #print('$$',text2.split())
#      16             if word in text2.split() and set(df.loc[i]["type"].split(',')).intersection(classes):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3748
#    3749         if is_scalar(loc):
# -> 3750             new_values = self._data.fast_xs(loc)
#    3751
#    3752             # may need to box a datelike-scalar
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in fast_xs(self, loc)
#     897
#     898         # unique
# --> 899         dtype = _interleaved_dtype(self.blocks)
#     900
#     901         n = len(items)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/internals/managers.py in _interleaved_dtype(blocks)
#    1896         return None
#    1897
# -> 1898     return find_common_type([b.dtype for b in blocks])
#    1899
#    1900
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/dtypes/cast.py in find_common_type(types)
#    1162                 return np.object
#    1163
# -> 1164     return np.find_common_type(types, [])
#    1165
#    1166
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numerictypes.py in find_common_type(array_types, scalar_types)
#     655     scalar_types = [dtype(x) for x in scalar_types]
#     656
# --> 657     maxa = _can_coerce_all(array_types)
#     658     maxsc = _can_coerce_all(scalar_types)
#     659
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numerictypes.py in _can_coerce_all(dtypelist, start)
#     585     while thisind < __len_test_types:
#     586         newdtype = dtype(__test_types[thisind])
# --> 587         numcoerce = len([x for x in dtypelist if newdtype >= x])
#     588         if numcoerce == N:
#     589             return newdtype
#
# KeyboardInterrupt:
